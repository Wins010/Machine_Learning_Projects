# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook is used to perform exploratory data analysis on the dataset.

# %% [markdown]
# ## 1. Dataset Loading & Overview

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ### a. Loading the dataset

# %%
df = pd.read_csv('../data/raw/auto-mpg.csv')

# %% [markdown]
# ### b. Dataset Overview

# %% [markdown]
# First 5 rows of the dataset

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Checking column names, counts, and data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe(include="all")
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# #### cleaning (force numeric, drop bad rows)

# %%
for c in df.select_dtypes(include='object').columns:
    df[c] = df[c].astype(str).str.strip()
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['mpg']        = pd.to_numeric(df['mpg'],        errors='coerce')
df = df.dropna(subset=['horsepower','mpg']).reset_index(drop=True)

# %% [markdown]
# #### converting to arrays
# numpy arrays for manual math

# %%
X = df['horsepower'].to_numpy(dtype=float)
y = df['mpg'].to_numpy(dtype=float)

# %% [markdown]
# #### saving the processed data

# %%
os.makedirs("../data/processed", exist_ok=True)
df.to_csv("../data/processed/auto-mpg-clean.csv", index=False)
print("Saved to ../data/processed/auto-mpg-clean.csv")

print("Data saved to path: ")
# Out:
# Saved to ../data/processed/auto-mpg-clean.csv
# Data saved to path:

# %% [markdown]
# ## 2. Data visualization

# %% [markdown]
# ### a. Distribution of [ Feature ]

# %% [markdown]
# Visualizing the distribution of 'horsepower'

# %%
sns.histplot(df['horsepower'], bins=20, kde=True, color = 'violet' )
plt.title('Distribution of Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### b. Distribution of [ Target ]

# %% [markdown]
# Visualizing the distribution of 'mpg' (miles per gallon)

# %%
sns.histplot(df['mpg'], bins=30, kde=True, color = 'violet' )
plt.title('Distribution of MPG')
plt.xlabel('Miles per Gallon (MPG)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### c. MPG vs Horsepower [scatter plot]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='horsepower', y='mpg', data=df, color='blue')
plt.title("Horsepower vs MPG")
plt.show()
